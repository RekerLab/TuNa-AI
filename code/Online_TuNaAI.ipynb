# %% [markdown]
# #**Free that Tuna 🐟**!
#
# Welcome! Here you can use the **TuNaAI** platform — completely free! — to predict nanoparticle formation with minimal programming required.

# %%
# Please don't change anything in this part - just execute it! (estimated running time: 30s)
# %%capture
# !git clone https://github.com/RekerLab/TuNa-AI.git
# !bash ./TuNa-AI/code/setup.sh

import sys
sys.path.append('/content/TuNa-AI/code')
from env_setup import *

# %%
# Time to free that tuna!
display(dashboard)
